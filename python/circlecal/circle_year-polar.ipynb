# %%
from gcsa.event import Event
from gcsa.google_calendar import GoogleCalendar
from gcsa.recurrence import Recurrence, DAILY, SU, SA

import plotly.express as px
import plotly.graph_objects as go

import pandas as pd

from datetime import datetime, timedelta, date
import dateutil
from dateutil.parser import parse
from calendar import monthrange, month_name, day_name
import numpy as np
from circle_cal import Year_Data

# %%
#gcal = GoogleCalendar('keithwdavis@gmail.com',
#                          credentials_path="/Users/kdavis10/.config/.credentials/pygooglecal.apps.googleusercontent.com.json")
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=3681359253-cj6ds937cv5p30vn8tbms112bjplms95.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=rEBt2vVCmv4yNhHsJhByzPK1Le19GP&access_type=offline

# %%
y = Year_Data(2024)
ydict = y.to_dict()

# %%
fig = go.Figure()
d_to_degree = (360 / len(y))
dbase=np.array([0.95] * y.length().days)
dr=1 - dbase
fig.add_trace(go.Barpolar(base=dbase,
                          r=dr,
                          theta0 = -90,
                          dtheta = d_to_degree,
                          name="date",
                          hovertext=[d.date() for d in ydict["date"]],
                          #text = [d.day for d in ydict["date"]]
                         )
             )
#mbase=np.array([0.95] * y.length().days)
#mr=1 - base
#fig.add_trace(go.Barpolar(
#                          theta0 = -90,
#                          dtheta = (360 / len(month_name[1:])),
#                          name="month",
#                          hovertext=[d.date() for d in ydict["date"]]))
fig.update_layout(height=1000)
fig.show()

# %%
fig.layout
# Out:
# Layout({
#     'height': 1000, 'template': '...'
# })
